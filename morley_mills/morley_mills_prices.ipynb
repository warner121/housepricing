# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
def get_properties(page=1):    
    res = requests.get(f'https://www.rightmove.co.uk/house-prices/ng5-6jl.html?page={page}')
    soup = BeautifulSoup(res.text, 'html.parser')
    s = soup.find_all('script')[-2]
    d = json.loads(s.string[s.string.find('{'):])
    df = pd.DataFrame(d['results']['properties'])
    df = df.drop('transactions', axis=1).join(df.transactions.explode()).reset_index(drop=True)
    df = df.drop('transactions', axis=1).join(pd.json_normalize(df.transactions))
    return df

# %%
df = pd.concat([get_properties(page+1) for page in range(3)])

# %%
df['number'] = df.address.str.split(', ').str[0].astype(int)

# %%
df.to_csv('morley_mills_prices.csv', index=False)

# %%
df
# Out:
#                                               address propertyType  \
# 0   8, Morley Mills, Morley Street, Daybrook, Nott...         Flat
# 1   8, Morley Mills, Morley Street, Daybrook, Nott...         Flat
# 2   8, Morley Mills, Morley Street, Daybrook, Nott...         Flat
# 3   8, Morley Mills, Morley Street, Daybrook, Nott...         Flat
# 4   8, Morley Mills, Morley Street, Daybrook, Nott...         Flat
# ..                                                ...          ...
# 18  47, Morley Mills, Morley Street, Daybrook, Not...         Flat
# 19  20, Morley Mills, Morley Street, Daybrook, Not...         Flat
# 20  17, Morley Mills, Morley Street, Daybrook, Not...         Flat
# 21  29, Morley Mills, Morley Street, Daybrook, Not...         Flat
# 22  34, Morley Mills, Morley Street, Daybrook, Not...         Flat
#
#                                                images  hasFloorPlan  \
# 0   {'imageUrl': '/spw/images/placeholder/no-image...         False
# 1   {'imageUrl': '/spw/images/placeholder/no-image...         False
# 2   {'imageUrl': '/spw/images/placeholder/no-image...         False
# 3   {'imageUrl': '/spw/images/placeholder/no-image...         False
# 4   {'imageUrl': '/spw/images/placeholder/no-image...         False
# ..                                                ...           ...
# 18  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 19  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 20  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 21  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 22  {'imageUrl': '/spw/images/placeholder/no-image...         False
#
#                               location  \
# 0   {'lat': 52.99703, 'lng': -1.13713}
# 1   {'lat': 52.99703, 'lng': -1.13713}
# 2   {'lat': 52.99703, 'lng': -1.13713}
# 3   {'lat': 52.99703, 'lng': -1.13713}
# 4   {'lat': 52.99703, 'lng': -1.13713}
# ..                                 ...
# 18  {'lat': 52.99703, 'lng': -1.13713}
# 19  {'lat': 52.99703, 'lng': -1.13713}
# 20  {'lat': 52.99703, 'lng': -1.13713}
# 21  {'lat': 52.99703, 'lng': -1.13713}
# 22  {'lat': 52.99703, 'lng': -1.13713}
#
#                                             detailUrl displayPrice  \
# 0   https://www.rightmove.co.uk/house-prices/detai...     £191,000
# 1   https://www.rightmove.co.uk/house-prices/detai...     £156,000
# 2   https://www.rightmove.co.uk/house-prices/detai...     £140,000
# 3   https://www.rightmove.co.uk/house-prices/detai...     £135,730
# 4   https://www.rightmove.co.uk/house-prices/detai...     £110,000
# ..                                                ...          ...
# 18  https://www.rightmove.co.uk/house-prices/detai...      £80,000
# 19  https://www.rightmove.co.uk/house-prices/detai...      £75,000
# 20  https://www.rightmove.co.uk/house-prices/detai...     £130,000
# 21  https://www.rightmove.co.uk/house-prices/detai...     £120,000
# 22  https://www.rightmove.co.uk/house-prices/detai...      £85,000
#
#        dateSold     tenure  newBuild  number
# 0   15 Jul 2024  Leasehold     False       8
# 1   12 Apr 2019  Leasehold     False       8
# 2   14 Aug 2015  Leasehold     False       8
# 3    2 Aug 2013  Leasehold     False       8
# 4   21 Jun 2001  Leasehold     False       8
# ..          ...        ...       ...     ...
# 18  14 Sep 2001  Leasehold     False      47
# 19  29 Jun 2001  Leasehold      True      20
# 20  29 Jun 2001  Leasehold     False      17
# 21  22 Jun 2001  Leasehold     False      29
# 22  19 Jun 2001  Leasehold     False      34
#
# [195 rows x 11 columns]
