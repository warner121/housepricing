# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
def get_properties(page=1):    
    res = requests.get(f'https://www.rightmove.co.uk/house-prices/sw11-1lu.html?page={page}')
    soup = BeautifulSoup(res.text, 'html.parser')
    s = soup.find_all('script')[-2]
    d = json.loads(s.string[s.string.find('{'):])
    df = pd.DataFrame(d['results']['properties'])
    df = df.drop('transactions', axis=1).join(df.transactions.explode()).reset_index(drop=True)
    df = df.drop('transactions', axis=1).join(pd.json_normalize(df.transactions))
    return df

# %%
df = pd.concat([get_properties(page+1) for page in range(1)]).reset_index(drop=True)

# %%
df['numericPrice'] = pd.to_numeric(df.displayPrice.str.replace('£', '').str.replace(',', ''))

# %%
df_address = df.address.str.split(', ').explode().to_frame()

# %%
postcode_regex = r'[A-Z]{1,2}[0-9]{1,2}[ ]{0,1}[0-9]{1,2}[A-Z]{1,2}$'
df_address['postcode'] = df_address.address.str.extract(f'({postcode_regex})')
df_address.address = df_address.apply(lambda x: x.address if isinstance(x.postcode, float) else x.address.replace(x.postcode, ''), axis=1)

# %%
df_address['number'] = pd.to_numeric(df_address.address.str.replace(r'[^0-9]*$', '', regex=True), errors='coerce')
df_address['number'] = df_address.apply(lambda x: x.address if x.number > 0 else None, axis=1)

# %%
df_address['prefix'] = df_address.number.notna().groupby(level=0).cumsum() == 0
df_address['prefix'] = df_address.apply(lambda x: x.address if x.prefix else None, axis=1)

# %%
df_address.loc[df_address.notna().sum(axis=1) > 1, 'address'] = None

# %%
address_to_idx = [None] + df_address.address.dropna().drop_duplicates().tolist()
df_address['counter'] = df_address.address.apply(lambda x: address_to_idx.index(x)).replace({0: None})
df_address['counter'] = df_address.counter.groupby(level=0).rank(method='first').convert_dtypes()

# %%
df_address_melt = df_address.reset_index().melt(id_vars=['index', 'counter']).dropna(subset='value')

# %%
df_address_melt['column'] = (df_address_melt.variable + '_' + df_address_melt.counter.astype(str)).str.replace('_<NA>', '')

# %%
df_address = df_address_melt.pivot(index='index', columns='column', values='value')

# %%
df = df.join(df_address)

# %%
df.to_csv('parma_crescent_prices.csv', index=False)

# %%
df
# Out:
#                                               address propertyType  bedrooms  \
# 0   76, Parma Crescent, London, Greater London SW1...     Terraced       5.0
# 1   76, Parma Crescent, London, Greater London SW1...     Terraced       5.0
# 2   76, Parma Crescent, London, Greater London SW1...     Terraced       5.0
# 3   76, Parma Crescent, London, Greater London SW1...     Terraced       5.0
# 4   60, Parma Crescent, London, Greater London SW1...     Terraced       2.0
# 5   60, Parma Crescent, London, Greater London SW1...     Terraced       2.0
# 6   Flat B, 73, Parma Crescent, London, Greater Lo...         Flat       1.0
# 7   Flat B, 73, Parma Crescent, London, Greater Lo...         Flat       1.0
# 8   Flat B, 73, Parma Crescent, London, Greater Lo...         Flat       1.0
# 9   Flat B, 73, Parma Crescent, London, Greater Lo...         Flat       1.0
# 10  73a, Parma Crescent, London, Greater London SW...         Flat       1.0
# 11  73a, Parma Crescent, London, Greater London SW...         Flat       1.0
# 12  73a, Parma Crescent, London, Greater London SW...         Flat       1.0
# 13  73a, Parma Crescent, London, Greater London SW...         Flat       1.0
# 14  73a, Parma Crescent, London, Greater London SW...         Flat       1.0
# 15  Ground Floor Flat, 74, Parma Crescent, London,...         Flat       3.0
# 16  Ground Floor Flat, 74, Parma Crescent, London,...         Flat       3.0
# 17  Ground Floor Flat, 74, Parma Crescent, London,...         Flat       3.0
# 18  55a, Parma Crescent, London, Greater London SW...     Terraced       2.0
# 19  55a, Parma Crescent, London, Greater London SW...     Terraced       2.0
# 20  63, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 21  63, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 22  63, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 23  63, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 24  56, Parma Crescent, London, Greater London SW1...     Terraced       3.0
# 25  75, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 26  75, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 27  75, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 28  75, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 29  75, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 30  62, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 31  62, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 32  57, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 33  57, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 34  57, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 35  67, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 36  67, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 37  67, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 38  67, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 39  Ground Floor Flat, 64, Parma Crescent, London,...         Flat       2.0
# 40  Ground Floor Flat, 64, Parma Crescent, London,...         Flat       2.0
# 41  55, Parma Crescent, London, Greater London SW1...         Flat       2.0
# 42  55, Parma Crescent, London, Greater London SW1...         Flat       2.0
# 43  55, Parma Crescent, London, Greater London SW1...         Flat       2.0
# 44  68, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 45  68, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 46  68, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 47  68, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 48  Top Floor Flat, 74, Parma Crescent, London, Gr...         Flat       3.0
# 49  Top Floor Flat, 74, Parma Crescent, London, Gr...         Flat       3.0
# 50  69, Parma Crescent, London, Greater London SW1...     Terraced       NaN
# 51  71, Parma Crescent, London, Greater London SW1...     Terraced       4.0
# 52  64b, Parma Crescent, London, Greater London SW...         Flat       2.0
#
#                                                images  hasFloorPlan  \
# 0   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 1   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 2   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 3   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 4   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 5   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 6   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 7   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 8   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 9   {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 10  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 11  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 12  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 13  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 14  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 15  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 16  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 17  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 18  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 19  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 20  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 21  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 22  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 23  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 24  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 25  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 26  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 27  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 28  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 29  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 30  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 31  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 32  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 33  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 34  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 35  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 36  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 37  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 38  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 39  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 40  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 41  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 42  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 43  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 44  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 45  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 46  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 47  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 48  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 49  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 50  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 51  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
# 52  {'imageUrl': 'https://media.rightmove.co.uk/di...         False
#
#                              location  \
# 0   {'lat': 51.4622, 'lng': -0.16433}
# 1   {'lat': 51.4622, 'lng': -0.16433}
# 2   {'lat': 51.4622, 'lng': -0.16433}
# 3   {'lat': 51.4622, 'lng': -0.16433}
# 4   {'lat': 51.4622, 'lng': -0.16433}
# 5   {'lat': 51.4622, 'lng': -0.16433}
# 6   {'lat': 51.4622, 'lng': -0.16433}
# 7   {'lat': 51.4622, 'lng': -0.16433}
# 8   {'lat': 51.4622, 'lng': -0.16433}
# 9   {'lat': 51.4622, 'lng': -0.16433}
# 10  {'lat': 51.4622, 'lng': -0.16433}
# 11  {'lat': 51.4622, 'lng': -0.16433}
# 12  {'lat': 51.4622, 'lng': -0.16433}
# 13  {'lat': 51.4622, 'lng': -0.16433}
# 14  {'lat': 51.4622, 'lng': -0.16433}
# 15  {'lat': 51.4622, 'lng': -0.16433}
# 16  {'lat': 51.4622, 'lng': -0.16433}
# 17  {'lat': 51.4622, 'lng': -0.16433}
# 18  {'lat': 51.4622, 'lng': -0.16433}
# 19  {'lat': 51.4622, 'lng': -0.16433}
# 20  {'lat': 51.4622, 'lng': -0.16433}
# 21  {'lat': 51.4622, 'lng': -0.16433}
# 22  {'lat': 51.4622, 'lng': -0.16433}
# 23  {'lat': 51.4622, 'lng': -0.16433}
# 24  {'lat': 51.4622, 'lng': -0.16433}
# 25  {'lat': 51.4622, 'lng': -0.16433}
# 26  {'lat': 51.4622, 'lng': -0.16433}
# 27  {'lat': 51.4622, 'lng': -0.16433}
# 28  {'lat': 51.4622, 'lng': -0.16433}
# 29  {'lat': 51.4622, 'lng': -0.16433}
# 30  {'lat': 51.4622, 'lng': -0.16433}
# 31  {'lat': 51.4622, 'lng': -0.16433}
# 32  {'lat': 51.4622, 'lng': -0.16433}
# 33  {'lat': 51.4622, 'lng': -0.16433}
# 34  {'lat': 51.4622, 'lng': -0.16433}
# 35  {'lat': 51.4622, 'lng': -0.16433}
# 36  {'lat': 51.4622, 'lng': -0.16433}
# 37  {'lat': 51.4622, 'lng': -0.16433}
# 38  {'lat': 51.4622, 'lng': -0.16433}
# 39  {'lat': 51.4622, 'lng': -0.16433}
# 40  {'lat': 51.4622, 'lng': -0.16433}
# 41  {'lat': 51.4622, 'lng': -0.16433}
# 42  {'lat': 51.4622, 'lng': -0.16433}
# 43  {'lat': 51.4622, 'lng': -0.16433}
# 44  {'lat': 51.4622, 'lng': -0.16433}
# 45  {'lat': 51.4622, 'lng': -0.16433}
# 46  {'lat': 51.4622, 'lng': -0.16433}
# 47  {'lat': 51.4622, 'lng': -0.16433}
# 48  {'lat': 51.4622, 'lng': -0.16433}
# 37  19 Dec 1997   Freehold     False        250000  Parma Crescent    London
# 38   3 May 1996   Freehold     False        168000  Parma Crescent    London
# 39   1 Dec 2003  Leasehold     False        250000  Parma Crescent    London
# 40  11 Sep 1998  Leasehold     False        144000  Parma Crescent    London
# 41   4 Jul 2003  Leasehold     False        300000  Parma Crescent    London
# 42  16 Oct 1998  Leasehold     False        197500  Parma Crescent    London
# 43  18 Aug 1995  Leasehold     False         91200  Parma Crescent    London
# 44  20 Dec 2002   Freehold     False        480000  Parma Crescent    London
# 45  27 Jan 2000   Freehold     False        380000  Parma Crescent    London
# 46  24 Oct 1997   Freehold     False        265000  Parma Crescent    London
# 47  28 Jun 1996   Freehold     False        165000  Parma Crescent    London
# 48  17 Jun 2002  Leasehold     False        275000  Parma Crescent    London
# 49  15 Nov 1996  Leasehold     False        124500  Parma Crescent    London
# 50  10 May 2001   Freehold     False        425000  Parma Crescent    London
# 51   8 May 1998   Freehold     False        235000  Parma Crescent    London
# 52   9 May 1997  Leasehold     False        155000  Parma Crescent    London
#
#    number  postcode             prefix
# 0      76  SW11 1LU                NaN
# 1      76  SW11 1LU                NaN
# 2      76  SW11 1LU                NaN
# 3      76  SW11 1LU                NaN
# 4      60  SW11 1LU                NaN
# 5      60  SW11 1LU                NaN
# 6      73  SW11 1LU             Flat B
# 7      73  SW11 1LU             Flat B
# 8      73  SW11 1LU             Flat B
# 9      73  SW11 1LU             Flat B
# 10    73a  SW11 1LU                NaN
# 11    73a  SW11 1LU                NaN
# 12    73a  SW11 1LU                NaN
# 13    73a  SW11 1LU                NaN
# 14    73a  SW11 1LU                NaN
# 15     74  SW11 1LU  Ground Floor Flat
# 16     74  SW11 1LU  Ground Floor Flat
# 17     74  SW11 1LU  Ground Floor Flat
# 18    55a  SW11 1LU                NaN
# 19    55a  SW11 1LU                NaN
# 20     63  SW11 1LU                NaN
# 21     63  SW11 1LU                NaN
# 22     63  SW11 1LU                NaN
# 23     63  SW11 1LU                NaN
# 24     56  SW11 1LU                NaN
# 25     75  SW11 1LU                NaN
# 26     75  SW11 1LU                NaN
# 27     75  SW11 1LU                NaN
# 28     75  SW11 1LU                NaN
# 29     75  SW11 1LU                NaN
# 30     62  SW11 1LU                NaN
# 31     62  SW11 1LU                NaN
# 32     57  SW11 1LU                NaN
# 33     57  SW11 1LU                NaN
# 34     57  SW11 1LU                NaN
# 35     67  SW11 1LU                NaN
# 36     67  SW11 1LU                NaN
# 37     67  SW11 1LU                NaN
# 38     67  SW11 1LU                NaN
# 39     64  SW11 1LU  Ground Floor Flat
# 40     64  SW11 1LU  Ground Floor Flat
# 41     55  SW11 1LU                NaN
# 42     55  SW11 1LU                NaN
# 43     55  SW11 1LU                NaN
# 44     68  SW11 1LU                NaN
# 45     68  SW11 1LU                NaN
# 46     68  SW11 1LU                NaN
# 47     68  SW11 1LU                NaN
# 48     74  SW11 1LU     Top Floor Flat
# 49     74  SW11 1LU     Top Floor Flat
# 50     69  SW11 1LU                NaN
# 51     71  SW11 1LU                NaN
# 52    64b  SW11 1LU                NaN
